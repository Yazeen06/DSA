# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read Data

# %%
data=pd.read_csv('C:/Users/Dell/Downloads/week10.csv')

# %%
data
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.41744     8.059332  356.886136
# 1      9.092223  181.101509  17978.98634     6.546600  310.135738
# 2      5.584087  188.313324  28748.68774     7.544869  326.678363
# 3     10.223862  248.071735  28749.71654     7.513408  393.663395
# 4      8.635849  203.361523  13672.09176     4.563009  303.309771
# ...         ...         ...          ...          ...         ...
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       363.266516       18.436525       100.341674   4.628771
# ...

# %% [markdown]
# # Check Null Values

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# # Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and
# comment on your observations.

# %%
data[['Hardness','Sulfate','Organic_carbon']]
# Out:
#         Hardness     Sulfate  Organic_carbon
# 0     214.373394  356.886136       18.436525
# 1     181.101509  310.135738       11.558279
# 2     188.313324  326.678363        8.399735
# 3     248.071735  393.663395       13.789695
# 4     203.361523  303.309771       12.363817
# ...          ...         ...             ...
# 2006  215.047358  312.931021        9.899115
# 2007  207.321086  304.510230       16.217303
# 2008   94.812545  258.930600       16.172755
# 2009  186.659040  345.700257       12.067620
# 2010  193.681736  359.948574       13.894419
#
# [2011 rows x 3 columns]

# %%
sns.pairplot(data[['Hardness','Sulfate','Organic_carbon']])

# %%
sns.scatterplot(x=data['Hardness'],y=data['Sulfate'])
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Sulfate'>

# %%
sns.scatterplot(x=data['Organic_carbon'],y=data['Sulfate'])
# Out:
# <AxesSubplot:xlabel='Organic_carbon', ylabel='Sulfate'>

# %%
sns.scatterplot(x=data['Hardness'],y=data['Organic_carbon'])
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Organic_carbon'>

# %%
data['Hardness'].median()
# Out:
# 197.1918394

# %%
plt.figure(figsize=(16,8))
sns.distplot(data['Hardness'])
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Density'>

# %%
plt.figure(figsize=(16,8))
sns.distplot(data['Sulfate'])
# Out:
# <AxesSubplot:xlabel='Sulfate', ylabel='Density'>

# %%
plt.figure(figsize=(16,8))
sns.distplot(data['Organic_carbon'])
# Out:
# <AxesSubplot:xlabel='Organic_carbon', ylabel='Density'>

# %% [markdown]
# # correlation analysis

# %%
plt.figure(figsize=(16,8))
corr_matrix=data.corr()
sns.heatmap(corr_matrix,annot=True,linewidth=.4,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# correlation factor between

# %% [markdown]
# # ph and Chloramines

# %%
data[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %% [markdown]
# correlation factor is -0.024768 so both are weakly correlated

# %% [markdown]
# # ph and Conductivity

# %%
data[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %% [markdown]
# correlation factor is 0.014128 so both are weakly correlated
